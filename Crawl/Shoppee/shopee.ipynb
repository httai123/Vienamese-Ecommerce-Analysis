# %%
import pandas as pd

# %%
df = pd.read_csv('comment.csv')
df.head()
# Out:
#    Unnamed: 0          orderId      itemId     shopId        cmtId  rating  \
# 0           0  130077827285171  5295769022  402909593  10795967041       5
# 1           1  138438681261504  5295769022  402909593  11725752232       1
# 2           2  134236019209968  5295769022  402909593  11196947546       1
# 3           3  131175458201710  5295769022  402909593  10894027529       5
# 4           4  128257969227063  5295769022  402909593  10653318554       5
#
#                                              comment  ship_oversea region  \
# 0  Chất lượng sản phẩm:tốt\nĐúng với mô tả:không ...         False     vn
# 1  Đúng với mô tả:đúng mô tả\nChất lượng sản phẩm...         False     vn
# 2  Đúng với mô tả:giao hàng không đúng với sản ph...         False     vn
# 3  Đúng giống với mô tả shipper thân thiện vừa gi...         False     vn
# 4  Chất lượng sản phẩm:ok\nĐúng với mô tả:đúng vớ...         False     vn
#
#       userId  likes
# 0  928315737   58.0
# 1  867288009    2.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'orderId', 'itemId', 'shopId', 'cmtId', 'rating',
#        'comment', 'ship_oversea', 'region', 'userId', 'likes'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head(20)
# Out:
#             orderId      itemId     shopId        cmtId  rating  \
# 0   130077827285171  5295769022  402909593  10795967041       5
# 1   138438681261504  5295769022  402909593  11725752232       1
# 2   134236019209968  5295769022  402909593  11196947546       1
# 3   131175458201710  5295769022  402909593  10894027529       5
# 4   128257969227063  5295769022  402909593  10653318554       5
# 5   128955875281494  5295769022  402909593  10714051361       5
# 6   131888598253531  5295769022  402909593  10956670441       4
# 7   136197118232227  5295769022  402909593  11367522146       1
# 8   128417004271266  5295769022  402909593  10658888227       4
# 9   117009237298570  5295769022  402909593   9601489963       1
# 10  120591790201068  5295769022  402909593   9928153578       4
# 11  133629324285232  5295769022  402909593  11145389149       1
# 12  132729612281275  5295769022  402909593  11049230337       5
# 13  134330914278681  5295769022  402909593  11236138072       5
# ...

# %%
is_duplicated_row = df.duplicated(keep='first')
num_duplicates = is_duplicated_row.sum()

print(f"Tổng số hàng bị lặp lại trong DataFrame là: {num_duplicates}")
# Out:
# Tổng số hàng bị lặp lại trong DataFrame là: 0

# %%
prd =  pd.read_csv('product.csv')
prd.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0       itemid     shopid  \
# 0             0   5295769022  402909593
# 1             1   1428754739   17217586
# 2             2   1236186398    1657913
# 3             3  18817660412   51979390
# 4             4  21738838429  844451217
# ..          ...          ...        ...
# 495         495   4313467746  187617976
# 496         496   5217183204   89827191
# 497         497   4032637524   89827191
# 498         498   8711300389    7669738
# 499         499  18149587079   88201679
#
#                                                   name  \
# 0    [Mã ELHA9 giảm 15% đơn 50K] SẠC CỰC NHANH - PI...
# 1    Sim 4G Mobifone MDT250A, 12MAX90, 12FD50, EDU ...
# 2    Điện Thoại Nokia 101,Nokia 100, Nokia 105 Zin ...
# 3    Kính cường lực 9H bảo vệ cho Căn cước công dân...
# 4    Ốp Điện Thoại Nhựa Dẻo In Logo Thương Hiệu Cho...
# ..                                                 ...
# 495  Sim Vietnam tạo fb,shope,zalo,sen,lad,gmail,mm...
# ...

# %%
prd.columns
# Out:
# Index(['Unnamed: 0', 'itemid', 'shopid', 'name', 'label_ids', 'image',
#        'images', 'currency', 'stock', 'status',
#        ...
#        'coins_can_claim_cnt', 'item', 'ui_type', 'room_id', 'user_id',
#        'nick_name', 'product_banners', 'top_product_label', 'fashion_item',
#        'image_search'],
#       dtype='object', length=142)

# %%
prd = prd.drop('Unnamed: 0', axis=1)

# %%
is_duplicated = prd.duplicated(keep='first')
num_duplicate = is_duplicated.sum()

print(f"Tổng số hàng bị lặp lại trong DataFrame là: {num_duplicate}")
# Out:
# Tổng số hàng bị lặp lại trong DataFrame là: 0
